# %% [markdown]
# # The information flow within a swarm
# Here we are going to create the heatmaps in:
# > Oliveira, Marcos, et al. "Communication Diversity in Particle Swarm Optimizers." International Conference on Swarm Intelligence. Springer International Publishing, 2016. https://doi.org/10.1007/978-3-319-44427-7_7
#
# ```tex
# @inproceedings{oliveira2016communication,
#   title={Communication Diversity in Particle Swarm Optimizers},
#   author={Oliveira, Marcos and Pinheiro, Diego and Andrade, Bruno and Bastos-Filho, Carmelo and Menezes, Ronaldo},
#   booktitle={International Conference on Swarm Intelligence},
#   pages={77--88},
#   year={2016},
#   organization={Springer}
# }
# ```

# %%
import os; os.chdir("../")

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
from swarm_interaction_network.opt.giant_component_analysis_plotter import GiantComponentDeathPlotter
from swarm_interaction_network.opt.giant_component_analysis_helper import GiantComponentDeathHelper
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.9/asyncio/base_events.py", line 596, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.9/asyncio/base_events.py", line 1890, in _run_once
#     handle._run()
#   File "/usr/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_7589/2600806215.py", line 4, in <module>
#     from swarm_interaction_network.opt.giant_component_analysis_plotter import GiantComponentDeathPlotter
#   File "/home/lauren/git/forks/swarm_interaction_network/swarm_interaction_network/opt/giant_component_analysis_plotter.py", line 5, in <module>
#     from swarm_interaction_network.opt.plotter import Plotter
#   File "/home/lauren/git/forks/swarm_interaction_network/swarm_interaction_network/opt/plotter.py", line 11, in <module>
#     from fastcluster import *
#   File "/home/lauren/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/fastcluster.py", line 37, in <module>
#     from _fastcluster import linkage_wrap, linkage_vector_wrap
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 get_ipython().run_line_magic('config', "InlineBackend.figure_format = 'retina'")
#       3 import pandas as pd
# ----> 4 from swarm_interaction_network.opt.giant_component_analysis_plotter import GiantComponentDeathPlotter
#       5 from swarm_interaction_network.opt.giant_component_analysis_helper import GiantComponentDeathHelper
#
# File ~/git/forks/swarm_interaction_network/swarm_interaction_network/opt/giant_component_analysis_plotter.py:5
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib.gridspec as gridspec
# ----> 5 from swarm_interaction_network.opt.plotter import Plotter
#       6 from itertools import cycle
#       9 class GiantComponentDeathPlotter:
#
# File ~/git/forks/swarm_interaction_network/swarm_interaction_network/opt/plotter.py:11
#       9 from scipy.spatial.distance import pdist, squareform
#      10 from scipy.cluster.hierarchy import dendrogram
# ---> 11 from fastcluster import *
#      14 class Plotter:
#      15     def __init__(self):
#
# File ~/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/fastcluster.py:37
#      32     def pdist(*args, **kwargs):
#      33         raise ImportError('The fastcluster.linkage function cannot process '
#      34                           'vector data since the function '
#      35                           'scipy.spatial.distance.pdist could not be  '
#      36                           'imported.')
# ---> 37 from _fastcluster import linkage_wrap, linkage_vector_wrap
#      39 def single(D):
#      40     '''Single linkage clustering (alias). See the help on the “linkage”
#      41 function for further information.'''
#
# ImportError: numpy.core.multiarray failed to import

# %% [markdown]
# First we create interaction graphs using different time windows, then we remove the edges from the graphs based on the weight, and finally count the number of components that emerge.
#
# Let's follow this procedure for single simulations of the PSO with the swarm using different topologies:

# %% [markdown]
# ## Von Neumann

# %%
filename = './data/vonneumann_F06_15'

# %% [markdown]
# It might take time to evaluate the destruction of the graph, so we save the output in a ``hdf`` file.

# %%
# df = GiantComponentDeathHelper.get_number_of_component_different_time_windows(filename, calculate_on=1000)
# df.to_hdf(filename + "_components.hdf", 'df')

# %%
df = pd.read_hdf("./data/vonneumann_F06_15_components.hdf", 'df')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tables'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_hdf("./data/vonneumann_F06_15_components.hdf", 'df')
#
# File ~/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/pandas/io/pytables.py:426, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     423 if not exists:
#     424     raise FileNotFoundError(f"File {path_or_buf} does not exist")
# --> 426 store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     427 # can't auto open/close if we are using an iterator
#     428 # so delegate to the iterator
#     429 auto_close = True
#
# File ~/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/pandas/io/pytables.py:566, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     563 if "format" in kwargs:
#     564     raise ValueError("format is not a defined argument for HDFStore")
# --> 566 tables = import_optional_dependency("tables")
#     568 if complib is not None and complib not in tables.filters.all_complibs:
#     569     raise ValueError(
#     570         f"complib only supports {tables.filters.all_complibs} compression."
#     571     )
#
# File ~/git/forks/swarm_interaction_network/.venv2/lib/python3.9/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'pytables'.  Use pip or conda to install pytables.

# %% [markdown]
# Let's see the patterns of the interactions within the swarm:

# %%
GiantComponentDeathPlotter.giant_component_death_heatmap(df);

# %% [markdown]
# This is Fig 4. in the paper.

# %% [markdown]
# We can also use specific time windows:

# %%
import numpy as np
tws = np.arange(50, 500, 50)
tws
# Out:
# array([ 50, 100, 150, 200, 250, 300, 350, 400, 450])

# %%
filename = './data/vonneumann_F06_15.zip'
df = GiantComponentDeathHelper.get_number_of_component_different_time_windows(
    filename, calculate_on=1000, tws=tws)

# %%
import matplotlib.pyplot as plt
GiantComponentDeathPlotter.giant_component_death_heatmap(df);
plt.gca().set_xticks(range(len(tws)))
plt.gca().set_xticklabels(tws);

# %% [markdown]
# Let's take look at other topologies:

# %% [markdown]
# ## Global

# %%
filename = './data/global_F06_15'

# %% [markdown]
# It might take time to evaluate the destruction of the graph, so we save the output in a ``hdf`` file.

# %%
# df = GiantComponentDeathHelper.get_number_of_component_different_time_windows(filename, calculate_on=1000)
# df.to_hdf(filename + "_components.hdf", 'df')

# %%
df = pd.read_hdf(filename + "_components.hdf", 'df')

# %% [markdown]
# Let's see the patterns of the interactions within the swarm:

# %%
GiantComponentDeathPlotter.giant_component_death_heatmap(df);

# %% [markdown]
# ## Ring

# %%
filename = './data/ring_F06_15'

# %% [markdown]
# It might take time to evaluate the destruction of the graph, so we save the output in a ``hdf`` file.

# %%
# df = GiantComponentDeathHelper.get_number_of_component_different_time_windows(filename, calculate_on=1000)
# df.to_hdf(filename + "_components.hdf", 'df')

# %%
df = pd.read_hdf(filename + "_components.hdf", 'df')

# %% [markdown]
# Let's see the patterns of the interactions within the swarm:

# %%
GiantComponentDeathPlotter.giant_component_death_heatmap(df);

# %% [markdown]
# Let's see the patterns of the interactions within the swarm:

# %% [markdown]
# ## Dynamic

# %%
filename = './data/dynamicring_F06_15'

# %% [markdown]
# It might take time to evaluate the destruction of the graph, so we save the output in a ``hdf`` file.

# %%
# df = GiantComponentDeathHelper.get_number_of_component_different_time_windows(filename, calculate_on=1000)
# df.to_hdf(filename + "_components.hdf", 'df')

# %%
df = pd.read_hdf(filename + "_components.hdf", 'df')

# %% [markdown]
# Let's see the patterns of the interactions within the swarm:

# %%
GiantComponentDeathPlotter.giant_component_death_heatmap(df);
